# %% [markdown]
# #### Making interactive visualizations in Python Altair

# %%
import numpy as np
import pandas as pd
import altair as alt

# %%
df = pd.read_csv("Git\Visualization\melb_data.csv", usecols = ['Price',
                                             'Landsize',
                                             'Distance',
                                             'Type',
                                             'Regionname'])

df = df[(df.Price < 3_000_000) & (df.Landsize < 1200)].sample(n=1000).reset_index(drop=True)

df.head()
# Out:
#   Type      Price  Distance  Landsize                  Regionname
# 0    h   662500.0      32.3     649.0  South-Eastern Metropolitan
# 1    u   640000.0       7.7     626.0       Southern Metropolitan
# 2    h  1712000.0       4.6     342.0       Southern Metropolitan
# 3    h   815000.0      12.1     525.0       Northern Metropolitan
# 4    h   760000.0       7.0     472.0        Western Metropolitan

# %%
alt.Chart(df).mark_circle(size=50).encode(
    x = 'Price',
    y = 'Distance',
    color = 'Type'
).properties(
    height = 350, width = 500
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ![image](Downloads/visualization.png)

# %%
Selection = alt.selection_multi(fields=['Type'], bind='legend')

# %%
alt.Chart(df).mark_circle(size=50).encode(
    x = 'Price',
    y = 'Distance',
    color = 'Type'
).properties(
    height = 350, width = 500
).add_selection(
    Selection
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ![image](Downloads/visualization%20(1).png)

# %%
selection = alt.selection_interval()

# %%
chart1 = alt.Chart(df).mark_circle(size=50).encode(
    x = 'Price',
    y = 'Distance',
    color = 'Type'
).properties(
    height = 350, width = 500
).add_selection(
    selection
)

chart2 = alt.Chart(df).mark_bar().encode(
    alt.X('Price:Q', bin = True), alt.Y('count()')
).transform_filter(
    selection
)

# %%
chart1 | chart2
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ![image](Downloads/visualization%20(2).png)

# %% [markdown]
# Trying to better understand the concepts of selection and condition, swap the histogram and scatter plot, so choosing an area on the bar plot will correspond with the values on the scatter plot

# %%
selection = alt.selection_interval()

chart1 = alt.Chart(df).mark_circle(size=50).encode(
    x = 'Landsize',
    y = 'Distance',
    color= 'Type'
).properties(
    height=350, width = 500
).transform_filter(
    selection
)

chart2 = alt.Chart(df).mark_bar().encode(
     alt.X('count()'), alt.Y('Price:Q', bin=True)
).add_selection(
    selection
)

chart1 | chart2
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# ![image](Downloads/visualization%20(3).png)
